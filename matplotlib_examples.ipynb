# %%
from matplotlib import pyplot
import numpy
from mpl_toolkits import mplot3d

# %% [markdown]
# Creating Random Datatset
#
# choosing 200 random values between 0 to 50
# for each axis

# %%
x = numpy.random.randint(0,50,(200))
y = numpy.random.randint(0,50,(200))
z = numpy.random.randint(0,50,(200))

# %%
ax = pyplot.axes(projection='3d')
ax.scatter(x,y,z)
