# %%
from matplotlib import pyplot
import numpy
from mpl_toolkits import mplot3d

# %%
x = numpy.random.randint(0,50,(200))
y = numpy.random.randint(0,50,(200))
z = numpy.random.randint(0,50,(200))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5868\3892361771.py in <module>
# ----> 1 x = numpy.random.randint(0,50,0.1,(200))
#       2 y = numpy.random.randint(0,50,0.1,(200))
#       3 z = numpy.random.randint(0,50,0.1,(200))
#
# mtrand.pyx in numpy.random.mtrand.RandomState.randint()
#
# TypeError: Cannot interpret '200' as a data type

# %%
ax = pyplot.axes(projection='3d')
ax.plot(x,y,z)

# %%
pyplot.show()
